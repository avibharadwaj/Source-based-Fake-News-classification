# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
dataset1=pd.read_csv("../data/politics18/politics18.csv")

# %%
dataset1.shape
# Out:
# (15346, 7)

# %%
dataset1.ndim
# Out:
# 2

# %%
dataset1.info
# Out:
# <bound method DataFrame.info of                         author  \
# 0                    The Quint
# 1                Pushpesh Pant
# 2      Meeran Chadha Borwankar
# 3                 Mayukh Ghosh
# 4               Akanksha Kumar
# 5               Poonam Agarwal
# 6                    The Quint
# 7                  Indira Basu
# 8                 Kingshuk Nag
# 9                 Kota Neelima
# 10                 Arushi Vats
# 11                   The Quint
# 12            Aishwarya S Iyer
# 13                   The Quint
# 14                   Smitha TK
# 15         Sanjiv Krishan Sood
# 16                   The Quint
# 17               Srishti Tyagi
# 18                   The Quint
# 19             Amandeep Sandhu
# 20             The News Minute
# 21               David Devadas
# 22                   The Quint
# 23             The News Minute
# 24                   The Quint
# 25                Neeraj Gupta
# 26                         PTI
# 27                         PTI
# ...

# %%
dataset1.describe
# Out:
# <bound method NDFrame.describe of                         author  \
# 0                    The Quint
# 1                Pushpesh Pant
# 2      Meeran Chadha Borwankar
# 3                 Mayukh Ghosh
# 4               Akanksha Kumar
# 5               Poonam Agarwal
# 6                    The Quint
# 7                  Indira Basu
# 8                 Kingshuk Nag
# 9                 Kota Neelima
# 10                 Arushi Vats
# 11                   The Quint
# 12            Aishwarya S Iyer
# 13                   The Quint
# 14                   Smitha TK
# 15         Sanjiv Krishan Sood
# 16                   The Quint
# 17               Srishti Tyagi
# 18                   The Quint
# 19             Amandeep Sandhu
# 20             The News Minute
# 21               David Devadas
# 22                   The Quint
# 23             The News Minute
# 24                   The Quint
# 25                Neeraj Gupta
# 26                         PTI
# 27                         PTI
# ...

# %%
dataset1.isnull()
# Out:
#        author  content   date    tag  title    url  website
# 0       False    False  False  False  False  False    False
# 1       False    False  False  False  False  False    False
# 2       False    False  False  False  False  False    False
# 3       False    False  False  False  False  False    False
# 4       False    False  False  False  False  False    False
# 5       False    False  False  False  False  False    False
# 6       False    False  False  False  False  False    False
# 7       False    False  False  False  False  False    False
# 8       False    False  False  False  False  False    False
# 9       False    False  False  False  False  False    False
# 10      False    False  False  False  False  False    False
# 11      False    False  False  False  False  False    False
# 12      False    False  False  False  False  False    False
# 13      False    False  False  False  False  False    False
# 14      False    False  False  False  False  False    False
# ...

# %%
d_copy = dataset1.copy()

# %%
d_copy['title'] = d_copy['title'].str.lower() #lowercase
d_copy['title'] = d_copy['title'].str.replace(r'[^\w\s]+', '') #punctuations
d_copy['title'] = d_copy['title'].str.strip() #leading and ending white spaces
stop = stopwords.words('english')
d_copy['title'] = d_copy['title'].str.replace('\d+', '') #remove numbers
#removing stop words from title body
patt = r'\b(?:{})\b'.format('|'.join(stop))
d_copy['title_without_stopwords'] = d_copy['title'].str.replace(patt, '')
d_copy['title_without_stopwords'] = d_copy['title_without_stopwords'].str.replace(r'\s+', ' ')

# %%
#Text
d_copy['content'] = d_copy['content'].str.lower() #lowercase
d_copy['content'] = d_copy['content'].str.replace(r'[^\w\s]+', '') #punctuations
d_copy['content'] = d_copy['content'].str.strip() #leading and ending white spaces
d_copy['content'] = d_copy['content'].str.replace('\d+', '') #remove numbers
#removing stop words from text body
pat = r'\b(?:{})\b'.format('|'.join(stop))
d_copy['text_without_stopwords'] = d_copy['content'].str.replace(pat, '')
d_copy['text_without_stopwords'] = d_copy['text_without_stopwords'].str.replace(r'\s+', ' ')
d_copy['content'] = d_copy['content'].str.replace('\d+', '') #remove numbers
#removing stop words from text body
pat = r'\b(?:{})\b'.format('|'.join(stop))
d_copy['text_without_stopwords'] = d_copy['content'].str.replace(pat, '')
d_copy['text_without_stopwords'] = d_copy['text_without_stopwords'].str.replace(r'\s+', ' ')

# %%
d_copy.to_csv(r'C:\Users\dell\Desktop\BE\Politics\Datasets-master\data\politics18\clean.csv')

# %%
d_copy['hasImage']=0
d_copy['language']='english'
d_copy['main_img_url']='No Image URL'
d_copy['type']='NA'
d_copy['label']='NA'

# %%
d_copy.to_csv(r'C:\Users\dell\Desktop\BE\Politics\Datasets-master\data\politics18\clean2.csv')

# %%
dataset2=pd.read_csv("../data/politics18/final.csv", encoding="latin", index_col=0)

# %%
dataset2.describe
# Out:
# <bound method NDFrame.describe of            X                author                      published  \
# 1          0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 2          1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 3          2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 4          3                Fed Up  2016-11-01T05:22:00.000+02:00
# 5          4                Fed Up  2016-11-01T21:56:00.000+02:00
# 6          5     Barracuda Brigade  2016-11-02T16:31:28.550+02:00
# 7          6                Fed Up  2016-11-04T19:40:00.000+02:00
# 8          7                Fed Up  2016-11-05T01:19:00.000+02:00
# 9          8                Fed Up  2016-11-06T23:54:00.000+02:00
# 10         9                Fed Up  2016-11-07T02:43:00.000+02:00
# 11        10              EdJenner  2016-11-07T22:34:36.822+02:00
# 12        11                Fed Up  2016-11-09T17:28:00.000+02:00
# 13        12              EdJenner  2016-11-10T02:37:06.677+02:00
# ...

# %%
d_copy2= dataset2.copy()

# %%
d_copy2['article_url']='NA2'

# %%
d_copy2.to_csv(r'C:\Users\dell\Desktop\BE\Politics\Datasets-master\data\politics18\clean3.csv')

# %%
del d_copy['tag']

# %%
d_copy = d_copy.rename(columns={'date': 'published', 
                                'content': 'text',
                                'website': 'site_url', 
                                'url': 'article_url'
                               })

# %%
d_copy.to_csv(r'C:\Users\dell\Desktop\BE\Politics\Datasets-master\data\politics18\clean2.csv')

# %%
d_copy3 = pd.concat([d_copy, d_copy2], ignore_index=True)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
d_copy3.to_csv(r'C:\Users\dell\Desktop\BE\Politics\Datasets-master\data\politics18\clean4.csv')

# %%
d_copy.shape
# Out:
# (15346, 13)

# %%
d_copy2.shape
# Out:
# (17735, 14)

# %%
d_copy3.shape
# Out:
# (33081, 14)
